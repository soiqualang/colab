# %% [markdown]
# <a href="https://colab.research.google.com/github/soiqualang/colab/blob/master/python_crawl_kqsx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# git@github.com:soiqualang/python_crawl_kqsx.git
#
# https://github.com/soiqualang/python_crawl_kqsx.git

# %%
# !git clone https://github.com/soiqualang/python_crawl_kqsx.git
# Out:
# Cloning into 'python_crawl_kqsx'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 39 (delta 9), reused 35 (delta 7), pack-reused 0
# Unpacking objects: 100% (39/39), done.

# %%
cd python_crawl_kqsx
# Out:
# /content/python_crawl_kqsx

# %%
# !pip install scrapy

# %%
# !scrapy crawl xosokienthiet -o items.json
# Out:
# 2019-06-03 03:46:40 [scrapy.utils.log] INFO: Scrapy 1.6.0 started (bot: xskt)
# 2019-06-03 03:46:40 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.0, Python 3.6.7 (default, Oct 22 2018, 11:32:17) - [GCC 8.2.0], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Linux-4.14.79+-x86_64-with-Ubuntu-18.04-bionic
# 2019-06-03 03:46:40 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'xskt', 'FEED_FORMAT': 'json', 'FEED_URI': 'items.json', 'NEWSPIDER_MODULE': 'xskt.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['xskt.spiders']}
# 2019-06-03 03:46:40 [scrapy.extensions.telnet] INFO: Telnet Password: 288505411414bf8f
# 2019-06-03 03:46:40 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
# ...

# %%
# !scrapy crawl xosokienthiet
# Out:
# 2019-06-03 03:52:37 [scrapy.utils.log] INFO: Scrapy 1.6.0 started (bot: xskt)
# 2019-06-03 03:52:37 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.0, Python 3.6.7 (default, Oct 22 2018, 11:32:17) - [GCC 8.2.0], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Linux-4.14.79+-x86_64-with-Ubuntu-18.04-bionic
# 2019-06-03 03:52:37 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'xskt', 'FEED_FORMAT': 'json', 'NEWSPIDER_MODULE': 'xskt.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['xskt.spiders']}
# 2019-06-03 03:52:37 [scrapy.extensions.telnet] INFO: Telnet Password: ebab9b81911cc57f
# 2019-06-03 03:52:37 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...
